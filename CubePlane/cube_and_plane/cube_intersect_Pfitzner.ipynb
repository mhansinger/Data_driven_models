# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib inline

# %%
# define the some functions
def x1(d,phi,tet):
    return d * np.cos((phi)) * np.sin((tet))

def y1(d,phi,tet):
    return d * np.sin((phi)) * np.cos((tet))

def z1(tet):
    return d*np.cos((tet))

# %%
def freg(x,y,z,d,tet,phi):
    return (x- x1(d,phi,tet)) * x1(d,phi,tet)/d + (y - y1(d,phi,tet) * y1(d,phi,tet)/d + (z - z1(tet)) * z1(tet)/d)

# %%
def fregz(x,y,d,tet,phi):
    return (d*np.cos((tet)) - y * np.cos((phi))* np.tan((tet)) - x*np.sin((phi))*np.tan((tet))+
           d*np.cos(phi)*np.cos(phi)*np.sin(tet)*np.tan(tet) + d*np.sin(phi)*np.sin(phi)*np.sin(tet)*np.tan(tet))

# %%
# define x and y range
x_range = np.linspace(-0.5,0.5,100)
y_range = np.linspace(-0.5,0.5,100)

# %%
fregz(x=x_range,y=y_range,d=0,tet=np.pi/4,phi=np.pi/4)
# Out:
# array([ 0.70710678,  0.6928218 ,  0.67853681,  0.66425182,  0.64996684,
#         0.63568185,  0.62139687,  0.60711188,  0.5928269 ,  0.57854191,
#         0.56425693,  0.54997194,  0.53568696,  0.52140197,  0.50711698,
#         0.492832  ,  0.47854701,  0.46426203,  0.44997704,  0.43569206,
#         0.42140707,  0.40712209,  0.3928371 ,  0.37855212,  0.36426713,
#         0.34998214,  0.33569716,  0.32141217,  0.30712719,  0.2928422 ,
#         0.27855722,  0.26427223,  0.24998725,  0.23570226,  0.22141727,
#         0.20713229,  0.1928473 ,  0.17856232,  0.16427733,  0.14999235,
#         0.13570736,  0.12142238,  0.10713739,  0.09285241,  0.07856742,
#         0.06428243,  0.04999745,  0.03571246,  0.02142748,  0.00714249,
#        -0.00714249, -0.02142748, -0.03571246, -0.04999745, -0.06428243,
#        -0.07856742, -0.09285241, -0.10713739, -0.12142238, -0.13570736,
#        -0.14999235, -0.16427733, -0.17856232, -0.1928473 , -0.20713229,
#        -0.22141727, -0.23570226, -0.24998725, -0.26427223, -0.27855722,
#        -0.2928422 , -0.30712719, -0.32141217, -0.33569716, -0.34998214,
#        -0.36426713, -0.37855212, -0.3928371 , -0.40712209, -0.42140707,
#        -0.43569206, -0.44997704, -0.46426203, -0.47854701, -0.492832  ,
#        -0.50711698, -0.52140197, -0.53568696, -0.54997194, -0.56425693,
#        -0.57854191, -0.5928269 , -0.60711188, -0.62139687, -0.63568185,
#        -0.64996684, -0.66425182, -0.67853681, -0.6928218 , -0.70710678])

# %%
X,Y = np.meshgrid(x_range,y_range)
Z = fregz(x=X,y=Y,d=0,tet=np.pi/4,phi=np.pi/4)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_zlim3d(-0.5,0.5)

# Plot a 3D surface
ax.plot_surface(X, Y, Z)
ax.view_init(10, 30)
plt.show()
