# %%
# plot and predict the slices 

import tensorflow as tf
# set TF to 1.x
tf.compat.v1.disable_v2_behavior()

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os.path import join
import os

from sklearn.metrics import r2_score, mean_gamma_deviance, mean_tweedie_deviance#, mean_absolute_percentage_error

from utils.normalize_data import normalizeStandard, reTransformStandard, reTransformTarget

from typing import List

from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px

# %matplotlib inline

font = {'size'   : 16}

plt.rc('font', **font)

# %%
print(tf.__version__)

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# LIMIT GPU MEMORY USAGE
gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#   except RuntimeError as e:
#     print(e)

if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1028)])
    except RuntimeError as e:
        print(e)

        
        
plt.rcParams.update({'font.size': 16})
# Out:
# 2.3.1

# %%
# Specify the case you want to predict
CASE = 'UPRIME5'

# Specify the trained model you want to use
MODEL_CASE='UPRIME5UPRIME15'

USE_KEEP_OUT = True #False

# Specifiy the filter width to predict (as str 16 or 20 so far)
#FILTER_WIDTH=str(20)

path_to_test = '/home/max/HDD3_DNS/Planar/NX512/'+CASE+'/postProcess_DNN/'
path_to_models = '/home/max/Python/Data_driven_models/TF2/trained_models/UPRIME5UPRIME15'

# %%
# !ls /home/max/Python/Data_driven_models/TF2/trained_models/
# Out:
# all_features			     five_features  seven_features
# all_without_cbar		     four_features  six_features
# DNN_UPRIME5_nrns_400_blks_10_Log.h5  four_relevant  UPRIME5UPRIME15

# %%
# load a test file
if USE_KEEP_OUT:
    # keep out data with n=20
    myData_df = pd.read_parquet(join(path_to_test,'KEEP_OUT','filter_width_20_DNN_'+CASE+'_test.parquet')).sample(frac=0.3)
else:
    myData_df = pd.read_parquet(join(path_to_test,'TEST','test_'+CASE+'_1_Log.parquet')).sample(frac=0.1)


# data is already normed!!

columns = list(myData_df.columns)
print(columns)

myData_index = myData_df.index

# TODO: update FEATURES

# Features and Target
FEATURES: List[str] = [#'c_bar',
                       'c_tilde',
                       'omega_model_planar',
                       'UP_delta',
                       'SGS_flux',
                       'Delta_LES',
                       'mag_grad_c_tilde',
                       'mag_grad_U',
                       'c_prime']
    
TARGET: List[str] = ['omega_DNS_filtered']
# Out:
# ['c_bar', 'c_tilde', 'omega_DNS_filtered', 'omega_model_planar', 'mag_grad_U', 'mag_grad_c', 'mag_grad_c_tilde', 'norm_c_tilde_x', 'norm_c_tilde_y', 'norm_c_tilde_z', 'theta', 'phi', 'lambda_1', 'lambda_3', 'UP_delta', 'SGS_flux', 'c_prime', 'Delta_LES', 'filter_width']

# %%
#!ls /home/max/Python/Data_driven_models/TF2/trained_models/all_without_cbar

# %% [markdown]
# ## Get valid indices and load the model (Log transformed!)

# %%
# load the model

# this is the Standard scaled model!
DNN = tf.keras.models.load_model(join(path_to_models,'DNN_'+MODEL_CASE+'_nrns_200_blks_10_Log.h5'))

# load the moments for scaling
moments = pd.read_csv(join(path_to_test, 'moments_' + CASE + '_Log.csv'), index_col=0)

DNN.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 200)          1800        Input[0][0]
# __________________________________________________________________________________________________
# res1_branch2a (Dense)           (None, 200)          40200       dense[0][0]
# __________________________________________________________________________________________________
# bn1_branch2a (BatchNormalizatio (None, 200)          800         res1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 200)          0           bn1_branch2a[0][0]
# __________________________________________________________________________________________________
# res1_branch2b (Dense)           (None, 200)          40200       activation[0][0]
# __________________________________________________________________________________________________
# bn1_branch2b (BatchNormalizatio (None, 200)          800         res1_branch2b[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200)          0           bn1_branch2b[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200)          0           add[0][0]
# __________________________________________________________________________________________________
# res2_branch2a (Dense)           (None, 200)          40200       activation_1[0][0]
# __________________________________________________________________________________________________
# bn2_branch2a (BatchNormalizatio (None, 200)          800         res2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200)          0           bn2_branch2a[0][0]
# __________________________________________________________________________________________________
# res2_branch2b (Dense)           (None, 200)          40200       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2_branch2b (BatchNormalizatio (None, 200)          800         res2_branch2b[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200)          0           bn2_branch2b[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200)          0           add_1[0][0]
# __________________________________________________________________________________________________
# res3_branch2a (Dense)           (None, 200)          40200       activation_3[0][0]
# __________________________________________________________________________________________________
# bn3_branch2a (BatchNormalizatio (None, 200)          800         res3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200)          0           bn3_branch2a[0][0]
# __________________________________________________________________________________________________
# res3_branch2b (Dense)           (None, 200)          40200       activation_4[0][0]
# __________________________________________________________________________________________________
# bn3_branch2b (BatchNormalizatio (None, 200)          800         res3_branch2b[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 200)          0           bn3_branch2b[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200)          0           add_2[0][0]
# __________________________________________________________________________________________________
# res4_branch2a (Dense)           (None, 200)          40200       activation_5[0][0]
# __________________________________________________________________________________________________
# bn4_branch2a (BatchNormalizatio (None, 200)          800         res4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200)          0           bn4_branch2a[0][0]
# __________________________________________________________________________________________________
# res4_branch2b (Dense)           (None, 200)          40200       activation_6[0][0]
# __________________________________________________________________________________________________
# bn4_branch2b (BatchNormalizatio (None, 200)          800         res4_branch2b[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 200)          0           bn4_branch2b[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 200)          0           add_3[0][0]
# __________________________________________________________________________________________________
# res5_branch2a (Dense)           (None, 200)          40200       activation_7[0][0]
# __________________________________________________________________________________________________
# bn5_branch2a (BatchNormalizatio (None, 200)          800         res5_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 200)          0           bn5_branch2a[0][0]
# __________________________________________________________________________________________________
# res5_branch2b (Dense)           (None, 200)          40200       activation_8[0][0]
# __________________________________________________________________________________________________
# bn5_branch2b (BatchNormalizatio (None, 200)          800         res5_branch2b[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 200)          0           bn5_branch2b[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 200)          0           add_4[0][0]
# __________________________________________________________________________________________________
# res6_branch2a (Dense)           (None, 200)          40200       activation_9[0][0]
# __________________________________________________________________________________________________
# bn6_branch2a (BatchNormalizatio (None, 200)          800         res6_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 200)          0           bn6_branch2a[0][0]
# __________________________________________________________________________________________________
# res6_branch2b (Dense)           (None, 200)          40200       activation_10[0][0]
# __________________________________________________________________________________________________
# bn6_branch2b (BatchNormalizatio (None, 200)          800         res6_branch2b[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 200)          0           bn6_branch2b[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 200)          0           add_5[0][0]
# __________________________________________________________________________________________________
# res7_branch2a (Dense)           (None, 200)          40200       activation_11[0][0]
# __________________________________________________________________________________________________
# bn7_branch2a (BatchNormalizatio (None, 200)          800         res7_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 200)          0           bn7_branch2a[0][0]
# __________________________________________________________________________________________________
# res7_branch2b (Dense)           (None, 200)          40200       activation_12[0][0]
# __________________________________________________________________________________________________
# bn7_branch2b (BatchNormalizatio (None, 200)          800         res7_branch2b[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 200)          0           bn7_branch2b[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 200)          0           add_6[0][0]
# __________________________________________________________________________________________________
# res8_branch2a (Dense)           (None, 200)          40200       activation_13[0][0]
# __________________________________________________________________________________________________
# bn8_branch2a (BatchNormalizatio (None, 200)          800         res8_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 200)          0           bn8_branch2a[0][0]
# __________________________________________________________________________________________________
# res8_branch2b (Dense)           (None, 200)          40200       activation_14[0][0]
# __________________________________________________________________________________________________
# bn8_branch2b (BatchNormalizatio (None, 200)          800         res8_branch2b[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 200)          0           bn8_branch2b[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 200)          0           add_7[0][0]
# __________________________________________________________________________________________________
# res9_branch2a (Dense)           (None, 200)          40200       activation_15[0][0]
# __________________________________________________________________________________________________
# bn9_branch2a (BatchNormalizatio (None, 200)          800         res9_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 200)          0           bn9_branch2a[0][0]
# __________________________________________________________________________________________________
# res9_branch2b (Dense)           (None, 200)          40200       activation_16[0][0]
# __________________________________________________________________________________________________
# bn9_branch2b (BatchNormalizatio (None, 200)          800         res9_branch2b[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 200)          0           bn9_branch2b[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 200)          0           add_8[0][0]
# __________________________________________________________________________________________________
# res10_branch2a (Dense)          (None, 200)          40200       activation_17[0][0]
# __________________________________________________________________________________________________
# bn10_branch2a (BatchNormalizati (None, 200)          800         res10_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 200)          0           bn10_branch2a[0][0]
# __________________________________________________________________________________________________
# res10_branch2b (Dense)          (None, 200)          40200       activation_18[0][0]
# __________________________________________________________________________________________________
# bn10_branch2b (BatchNormalizati (None, 200)          800         res10_branch2b[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 200)          0           bn10_branch2b[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 200)          0           add_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            1608        activation_19[0][0]
# __________________________________________________________________________________________________
# add_layers (Add)                (None, 8)            0           dense_1[0][0]
#                                                                  Input[0][0]
# __________________________________________________________________________________________________
# prediction_layer (Dense)        (None, 1)            9           add_layers[0][0]
# ==================================================================================================
# Total params: 823,417
# Trainable params: 815,417
# Non-trainable params: 8,000
# __________________________________________________________________________________________________

# %%
print(join(path_to_models,'DNN_'+MODEL_CASE+'_nrns_200_blks_10_Log.h5'))
# Out:
# /home/max/Python/Data_driven_models/TF2/trained_models/UPRIME5UPRIME15/DNN_UPRIME5UPRIME15_nrns_200_blks_10_Log.h5

# %% [markdown]
# ## Transform and scale the data, then make the prediction

# %%
if USE_KEEP_OUT:
    
    myData_rescaled_df = myData_df.copy()
    
    # Normalize
    myData_norm_df = normalizeStandard(myData_df.apply(np.log),moments)
            
else:
    # Normalize
    myData_norm_df = normalizeStandard(myData_df,moments)

    myData_rescaled_df = myData_df.apply(np.exp)

# use myData_norm_df for the prediction with ANNs

# %%
plt.figure(figsize=(10,10))
plt.scatter(myData_df['c_tilde'],myData_norm_df['omega_DNS_filtered'])
plt.title('$\omega$')
# Out:
# Text(0.5, 1.0, '$\\omega$')

# %%
plt.figure(figsize=(10,8))
plt.hist(myData_df['omega_DNS_filtered'],bins=50,density=True)
plt.title('Historgram of log$(\overline{\omega}_{DNS})$')
plt.ylabel('Frequency')
plt.xlabel('log($\overline{c}$)')
# Out:
# Text(0.5, 0, 'log($\\overline{c}$)')

# %%
plt.figure(figsize=(10,8))
plt.hist(myData_norm_df['omega_DNS_filtered'],bins=50,density=True)
plt.title('Historgram of $\overline{\omega}_{DNS}$')
plt.ylabel('Frequency')
plt.xlabel('$\overline{c}$')
# Out:
# Text(0.5, 0, '$\\overline{c}$')

# %%
# get rid of unnecessary data
valid_index = myData_rescaled_df.loc[(myData_rescaled_df['c_tilde']<0.99) & (myData_rescaled_df['c_tilde']>0.01)].index.values

invalid_index = myData_rescaled_df.loc[(myData_rescaled_df['c_tilde']>0.99) | (myData_rescaled_df['c_tilde']<0.01)].index.values

# data frame with valid, masked 
myData_norm_df = myData_norm_df.loc[valid_index]

myData_norm_df = myData_norm_df[FEATURES+TARGET]

# %%
myData_norm_df.head()
# Out:
#          c_tilde  omega_model_planar  UP_delta  SGS_flux  Delta_LES  \
# 220878 -1.117956           -0.049611  0.646860  0.688118   0.722251
# 351759  0.798535            0.036279  0.993570  0.632761   1.091385
# 351759  0.949603            0.287237  0.369139 -0.048019   0.501357
# 307469 -0.067284            0.305199  1.056500  1.309387   0.501357
# 307469  0.170998            0.662849  0.390722  0.820258  -0.424385
#
#         mag_grad_c_tilde  mag_grad_U   c_prime  omega_DNS_filtered
# 220878         -1.083872   -0.630554  0.462214           -0.814816
# 351759         -0.577980   -1.229769  0.365285           -0.305399
# 351759         -0.376385   -0.689009 -0.245883           -0.185534
# 307469         -0.221459    0.079354  0.787052            0.405952
# 307469          0.695185    1.024606  0.449124            0.762470

# %%
################################
# make the prediction
omega_hat_norm = DNN.predict(myData_norm_df[FEATURES])
################################

# %%
omega_hat_rescaled = reTransformTarget(omega_hat_norm, moments)

omega_hat_predict_real = omega_hat_rescaled.apply(np.exp)

omega_DNS_filtered = myData_rescaled_df[TARGET].loc[valid_index]

# %% [markdown]
# ## Plot the correlation between prediction and true value

# %%
plt.figure(figsize=(10,10))
plt.scatter(omega_DNS_filtered,omega_hat_predict_real,s=0.2)
plt.plot([0,1],[0,1],'k')
plt.title('Correlation of $\overline{\omega}_{DNS}$ and $\overline{\omega}_{ANN}$')
plt.xlabel('$\overline{\omega}_{DNS}$')
plt.ylabel('$\overline{\omega}_{ANN}$')
# Out:
# Text(0, 0.5, '$\\overline{\\omega}_{ANN}$')

# %% [markdown]
# ### R2 score

# %%
import scipy
print("R2:                 ",r2_score(omega_hat_predict_real, omega_DNS_filtered))
print("tweedy deviance:    ", mean_tweedie_deviance(omega_DNS_filtered,omega_hat_predict_real))
print("mean gamma deviance:", mean_gamma_deviance(omega_DNS_filtered,omega_hat_predict_real))
# Out:
# R2:                  0.9792833707239545
# tweedy deviance:     0.00054863375
# mean gamma deviance: 0.011096297

# %% [markdown]
# ## Compare omega vs c_tilde

# %%
plt.figure(figsize=(10,10))
plt.scatter(myData_rescaled_df['c_tilde'].loc[valid_index],myData_rescaled_df[TARGET].loc[valid_index],s=0.6,c='b')
plt.scatter(myData_rescaled_df['c_tilde'].loc[valid_index],omega_hat_predict_real,c='r',s=0.6)



plt.xlabel('$\widetilde{c}$')
plt.ylabel('$\overline{\omega}$')

if USE_KEEP_OUT:
    plt.scatter(myData_rescaled_df['c_bar'].loc[valid_index],myData_rescaled_df['omega_model_planar'].loc[valid_index],s=0.6,c='k')
    plt.title('True and predicted $\overline{\omega}$ for different n=20')
    plt.ylim([0,0.6])
else:
    plt.title('True and predicted $\overline{\omega}$ for different $\Delta$ on the test data')
    plt.ylim([0,1.2])


plt.legend(['$\overline{\omega}_{ANN}$ (red)','$\overline{\omega}_{DNS}$ (blue)','$\overline{\omega}_{m}$ (black)'],loc='upper left')
    
plt.xlim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Now apply the SHAP method

# %%
import shap
shap.initjs()

##############
# SHAP needs TF1.x
##############

# %%
SHAP_test_set = myData_norm_df[FEATURES].sample(n=1000, random_state=0).to_numpy()

explainer = shap.DeepExplainer(DNN, SHAP_test_set)

# %%
shap_values = explainer.shap_values(SHAP_test_set)

# %%
location = 100


shap.force_plot(explainer.expected_value, shap_values[0][location,:], myData_norm_df[FEATURES].iloc[location,:])

# %% [markdown]
# ## Feature importance

# %%
shap.summary_plot(shap_values[0], myData_norm_df[FEATURES].sample(100),plot_type="bar")

# %%
shap_values[0].shape
# Out:
# (1000, 8)
